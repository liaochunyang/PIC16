# %% [markdown]
# # Worksheet
#
#
# ### Group Members and Roles
#
# - Group Member 1 (Role)
# - Group Member 2 (Role)
# - Group Member 3 (Role)
#
# ## Grading policy:
#
# 1. Class docstring and method docstring. (4 pts)
# 2. Test examples. (4 pts)
# 3. Restart the kernel and run all before you submit. (1 pt)
# 4. Submit a pdf file. (1 pt)
#
#
# ## Exercise 1: Class of Triangles
#
# Follow the steps:
#
# - Create a class, Triangle. Its __init__() method should take self, angle1, angle2, and angle3 as arguments. Make sure to set these appropriately in the body of the __init__()method.
#
# - Create a variable named number_of_sides and set it equal to 3.
#
# - Create a method named check_angles. It should return True if the sum of self.angle1, self.angle2, and self.angle3 is equal 180, and False otherwise.
#
# - Create a method named right_triangle. It should return True if one of self.angle1, self.angle2, and self.angle3 is equal 90, and False otherwise.
#
# - create a method named isosceles_triangle. It should return True if two of self.angle1, self.angle2, and self.angle3 are equal, and False otherwise.
#
# - Create a method named equilateral_triangle. It should return True if self.angle1 = self.angle2 = self.angle3 = 60, and False otherwise.

# %%
# Your solution goes here

# %%
# Test 1:
my_triangle=Triangle(90,30,60)
print(my_triangle.check_angles())             # Should print True
print(my_triangle.right_triangle())           # Should print True
print(my_triangle.isosceles_triangle())       # Should print False
print(my_triangle.equilateral_triangle())     # Should print False

# %%
# Test 2:
my_triangle=Triangle(120,30,30)
print(my_triangle.check_angles())              # True
print(my_triangle.right_triangle())            # False
print(my_triangle.isosceles_triangle())        # True
print(my_triangle.equilateral_triangle())      # False

# %%
# Test 3:
my_triangle=Triangle(60,60,60)
print(my_triangle.check_angles())              # True
print(my_triangle.right_triangle())            # False
print(my_triangle.isosceles_triangle())        # True
print(my_triangle.equilateral_triangle())      # True

# %% [markdown]
# # Exercise 2:
#
# (a) In this part, we define a new operation "+" for integers. Please do the following:
#
# - Create a class named **new_int**. Its initialization \_\_init\_\_ take self and x as arguments. For each instance, there is one attribute called x and we assign input x to instance attribute x. In other words, we define an instance variable self.x with assigned value x passing from \_\_init\_\_.
#
#
# - Define magic method `\_\_add\_\_`. Given two instances self and other, \_\_add\_\_ computes the sum of self.x and other.x, divides the sum by 5 and returns the remainder.

# %%
# Your solution here

# %%
# Test example 1:
a = new_int(1)
b = new_int(8)
a+b         # should print 4

# %%
# Test example 2:
a = new_int(-6)
b = new_int(-3)
a+b         # should print 1

# %% [markdown]
# (b) Notice that if you run the following code, you will see an object instead of a number since we do not define \_\_str\_\_ and \_\_repr\_\_
#
#     print(int1,int2)
#
# In this exercise, define magic method \_\_str\_\_ and \_\_repr\_\_ and the expected results are:
#
#     int1 = new_int(6)
#     int1
#     # should print 6                # number only no parenthesis
#
#     print(int1)
#     # should print (6)              # be carefule parenthesis here

# %%
# Your solution here

# %%
# Test example:
int1 = new_int(6)
int1       # should print 6

# %%
print(int1)     # should print (6)

# %% [markdown]
# (c) Look at the following example which explains that
#
# `a+=5` is equivalent to `a = a+5`, it means that a is updated by a+5.

# %%
a = 5
a+=5
a

# %% [markdown]
# We can use magic method \_\_iadd\_\_ to define operation `+=` for class.
#
# In this exercise, we want to define `+=` for integers.
#
# - Define magic method \_\_add\_\_. Given two instances self and other, \_\_iadd\_\_ computes self.x + 2*other.x and assigns the new value to self.x, i.e.
#
#
#       self.x += other.x
#
# will make
#
#     self.x = self.x + 2*other.x and other.x = other.x

# %%
# Your solution here. 

# Please also include __str__ and __repr__ in part(b) here, otherwise you may see different print output.

# %%
# Test example
int1 = new_int(5)
int2 = new_int(10)
int1 += int2
print(int1,int2)        # should print (25), (10)

# %%
int1
# should print 25

# %%
int2
# should print 10
