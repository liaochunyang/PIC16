# %% [markdown]
# # Worksheet
#
#
# ### Group Members and Roles
#
# - Group Member 1 (Role)
# - Group Member 2 (Role)
# - Group Member 3 (Role)
#
#
# ## Part A
#
# Run the following cell to load the obesity dataset as a `pandas` `DataFrame` called `obsesity`.
#
# Shorten columns' names for `family_history_with_overweight` and `NObeyesdad`.
#
#
# While working with this dataset, you may notice some blank or nonsensical values.  Normally, for a project such as this, we would want to remove these values before we continue.  However, in this worksheet you can just ignore them.

# %%
import pandas as pd
import numpy as np
import urllib
from matplotlib import pyplot as plt

url = "https://raw.githubusercontent.com/liaochunyang/PIC16/refs/heads/main/PIC16A/data/Obsesity.csv"
obesity = pd.read_csv(url)
obesity
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS           NObeyesdad
# 0             no  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 2     Frequently  Public_Transportation        Normal_Weight
# 3     Frequently                Walking   Overweight_Level_I
# 4      Sometimes  Public_Transportation  Overweight_Level_II
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
# optional code here if you need to refresh your memory of the data set

# %% [markdown]
# ## Part B
#
# Write a function called `penguin_summary_table` which accepts two arguments, `group_cols` and `value_cols`. This function should create a table in which the mean of each element of `value_cols` is shown, grouped according to the specified `group_cols`. For example, the call
#
# ```python
# penguin_summary_table(["Gender"], ["Height", "Weight"])
# ```
#
# should produce a summary table with the mean height and weight per gender.
#
# For a more pleasant display, **round the numbers in your table to 2 decimal places**.
#
# This function can be implemented in just a few lines. Comments and docstrings are not necessary.

# %%
# your solution here

# %% [markdown]
# ## Part  C
#
# Use your function to explore the data a bit. Focus on the numerical variables:
#
# - `Age`
# - `Height`
# - `Weight`
# - `CH20`
#
#
# **Create at least three readable summary tables.** Then, work with your group mates to explain the significance of each table. Do you observe any important differences between the obesity level?
#
# Make sure that each table has a message, and that no information is shown that is not part of that message. Is there a part of the table that you have nothing to say about? Remove it!

# %%
# Table 1

# %% [markdown]
# #### Discussion of Table 1

# %%
# Table 2

# %% [markdown]
# #### Discussion of Table 2

# %%
# Table 3

# %% [markdown]
# #### Discussion of Table 3
