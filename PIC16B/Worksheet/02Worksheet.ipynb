# %% [markdown]
# # Worksheet: Data manipulation and visualization
#
#
# ## Previous work
#
# Recall the previous worksheet where you produce the following pandas data frame
#
# ![w2.png](attachment:w2.png)
#
#
# The instructions are given below. You do not need to repeat what you have done. In other words, you can use any codes and functions in the first worksheet.
#
# #### Part 1: Concatenate vs merge
#
# Read documentations [pandas.concat](https://pandas.pydata.org/docs/reference/api/pandas.concat.html) and [pandas.merge](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge.html), then use your own words (one or two lines) to state the differences.
#
# #### Part 2: Combine two dataframes to one
#
# Given the following temperature datasets, merge them to a large dataframe
#
# - temperature data: https://raw.githubusercontent.com/liaochunyang/PIC16/main/PIC16B/01_Visualization/decades/1901-1910.csv
#
# - temperature data: https://raw.githubusercontent.com/liaochunyang/PIC16/main/PIC16B/01_Visualization/decades/2011-2020.csv
#
# #### Part 3
#
# Write a function, which takes two dataframes as inputs and returns a new dataframe, to do data manipulation.
#
# Inputs:
#
# - `df1: temperature data.`
# - `df2: country-code data.` This is the same dataframe I use during the lecture, which can be found here: https://raw.githubusercontent.com/liaochunyang/PIC16/main/PIC16B/01_Visualization/fips-10-4-to-iso-country-codes.csv
#
# Outputs:
# - `df3: a new dataframe including several columns (see example below)`

# %% [markdown]
# ## Instructions of this worksheet:
#
# Follow the instructions to finish this worksheet.
#
#
# ### Part 1: Average temperature
#
# The goal of this part is to write a function to compute the average temperature given a country and a month. The output of this function be a sentence (you may use `print` inside your function, see example below). The solution is not unique, you can use any methods in pandas.
#
# This page is helpful if you want to convert a number to month name: https://stackoverflow.com/questions/6557553/get-month-name-from-number
#
# **Desired ouptput:** After calling the function (`average` is my function name ), the desired output looks like
# ![w3.jpg](attachment:w3.jpg)

# %%
# test example
average(df, country="Zimbabwe", month=1)

# %% [markdown]
# ### Part 2: Data visualization
#
# The goal of this part is to visualize the year average temperature. Notice that two temperature datasets are given, one is from 1901 to 1910 and the other is from 2011 to 2020.
#
# You should write a function to do this and the output of your function is a plot with two lines (one is for 1901-1910 and the other is for 2011-2020), see example below.
#
# The average temperature change plot for Zimbabwe is shown as
# ![w3_1.png](https://raw.githubusercontent.com/liaochunyang/PIC16/refs/heads/main/PIC16B/01_Visualization/w3_1.png)
#
# You are expect to create a similar plot for any country, which means country name should be one of the function inputs. However, x-labels, y-labels, plot title and etc are missing in my plot, you should also add informative labels and legends for your plot.

# %% [markdown]
# If time permits, please include function docstring for your functions.
#
# #### Submission guidelines:
#
# 1. Please **restart the kernel and run all** before you submit. (menu bar -> kernel -> Restart & Run all)
# 2. Render the notebook to a pdf file (menu bar -> file -> print preview -> save as pdf).
# 3. Submit the pdf version to Gradescope. Make sure that all of your code and results show properly in the pdf file.
#
# #### Grading items:
#
# 1. Test example in part 1. (+2 pts)
#
# 2. Clear and informative figure labels, legends, titles and etc. (+2 pts)
#
# 3. Participation -- You submit a worksheet with related code. (+4 pts)
#
# 4. Short in-line comments are required to explain your code. (+2 pts)
