# %% [markdown]
# # Worksheet: Covid data visualization
#
#
# The goal of this worksheet is to visualize covid data using plotly. There is no desired outputs for this worksheet. You can visualize the data using any plots you like. However, there are several requirements:
#
# - You can only use plotly to do the visualization. You can use pandas and numpy for data cleaning.
#
# - You should include at least one of scatter plot, bar plot, histogram, and line plot. Clear and informative figure legends, title, and labels are required.
#
# - You should include one choropleth map.
#
# - Documentations are required to explain your code and results.
#
# Here are some remarks:
#
# - In the dataset, there are 243 countries. To save running time, you should select a subset of countries.
#
# - Also, you are also allowed to select a specific time range since the dataset contains a long time range. Please make sure that your selection is not empty, otherwise your plot is empty.
#
# - No need to write a function for this exercise.

# %%
# link to covid dataset
url = 'https://raw.githubusercontent.com/liaochunyang/PIC16/main/PIC16B/01_Visualization/global-data.csv'

# %% [markdown]
# #### Submission guidelines:
#
# 1. Please **restart the kernel and run all** before you submit.
# 2. Render the notebook to a pdf file (menu bar -> file -> print preview -> save as pdf).
# 3. Submit the pdf version to Gradescope. Make sure that all of your code and results show properly in the pdf file.
#
# #### Grading items:
#
# 1. Participation and completion.
