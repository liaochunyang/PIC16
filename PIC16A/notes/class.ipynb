# %% [markdown]
# # Class

# %% [markdown]
# Exercise. Create a class Circle that takes a radius as a parameter. Add methods to calculate the area and circumference of the circle.

# %%
import math
class Circle:
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return math.pi * self.radius ** 2
    def circumference(self):
        return 2 * math.pi * self.radius
# Test
c = Circle(5)
print("Area:", c.area())
print("Circumference:", c.circumference())

# %% [markdown]
# Exercise. Create a class Person with two attributes: name and age. Add a method greet()
# that prints ”Hello, my name is name and I am age years old.”

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")
# Test
p = Person("Alice", 30)
p.greet()

# %% [markdown]
# Exercise. Create a BankAccount class with methods deposit(), withdraw(), and get balance().
# Prevent withdrawal if it would cause a negative balance.

# %%
class BankAccount:
    def __init__(self, balance=0):
        self.balance = balance
    def deposit(self, amount):
        self.balance += amount
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
        else:
            print("Insufficient funds!")
    def get_balance(self):
        return self.balance
# Test
account = BankAccount()
account.deposit(100)
account.withdraw(30)
account.withdraw(100)
print("Balance:", account.get_balance())

# %% [markdown]
# Exercise. Create a class Student that stores a student’s name and a list of grades. Add
# methods to add a grade and calculate the average grade.

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.grades = []
    def add_grade(self, grade):
        self.grades.append(grade)
    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)
# Test
s = Student("John")
s.add_grade(80)
s.add_grade(90)
s.add_grade(70)
print(f"{s.name}’s average grade is {s.average_grade()}")

# %% [markdown]
# Exercise. Task: Create a class StorageBox that represents a box in a storage facility. Each
# box has: label (a name for the box) capacity (maximum number of items it can hold) items
# (a list to store item names) Add methods to: add item(item name) – adds an item if there is
# space remove item(item name) – removes the item if it exists list items() – prints all items
# in the box

# %%
class StorageBox:
    def __init__(self, label, capacity):
        self.label = label
        self.capacity = capacity
        self.items = []
    def add_item(self, item_name):
        if len(self.items) < self.capacity:
            self.items.append(item_name)
            print(f"Added ’{item_name}’ to box ’{self.label}’.")
        else:
            print(f"Box ’{self.label}’ is full! Cannot add ’{item_name}’.")
    def remove_item(self, item_name):
        if item_name in self.items:
            self.items.remove(item_name)
            print(f"Removed ’{item_name}’ from box ’{self.label}’.")
        else:
            print(f"Item ’{item_name}’ not found in box ’{self.label}’.")
    def list_items(self):
        print(f"Items in box ’{self.label}’: {’, ’.join(self.items) if self.items else ’
# Test
box = StorageBox("Box A", 3)
box.add_item("Book")
box.add_item("Laptop")
box.add_item("Camera")
box.add_item("Phone") # Should show box is full
box.list_items()
box.remove_item("Laptop")
box.list_items()

# %% [markdown]
# Exercise: Smart BankAccount Class
# #### Goal:
# Simulate real-world financial operations with operator overloading and clear representat
# #### Task:
# Design a class BankAccount that supports deposits, withdrawals, equality comparison, and
# #### Requirements:
# **Attributes:**
# - owner: account holder’s name
# - balance: float
# **Methods:**
# - deposit(self, amount) and withdraw(self, amount)
# **Magic Methods:**
# - \_\_add\_\_(self, other) -> merge two accounts (sum balances, combine owners as a stri
# - \_\_iadd\_\_(self, amount) -> deposit money via +=
# - \_\_eq\_\_(self, other) -> two accounts are equal if balances are equal
# - \_\_str\_\_(self) -> human-readable summary
# - \_\_repr\_\_(self) -> full technical representation
