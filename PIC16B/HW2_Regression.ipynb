# %% [markdown]
# # HW2: Regression
#
# ## Goal:
#
# The goal of this assignment is to develop, evaluate, and interpret regression models to predict a continuous target variable using real-world data.
# After this assignment, I hope you are familiar with the machine learning pipeline.
#
# ## Dataset:
#
# Here is the link to the energy dataset: https://raw.githubusercontent.com/liaochunyang/PIC16/refs/heads/main/PIC16B/04_ML/energy.csv
#
# In this dataset, there are eight features ($X1,\dots, X8$) and two targets ($Y1,Y2$). Unlike the datasets I used in the lecture, there is no description for the features and targets.
#
# ## Task:
#
# Use this dataset to construct some regression models and report test errors. You can predict either $Y1$ or $Y2$. This is an open-ended assignment—feel free to explore different modeling approaches, preprocessing techniques, and evaluation strategies, and justify the choices you make.
#
# ## Minimum expectations:
#
# 1. You should use data visualization techniques to analyze your data. P.S. Since the dataset description is missing, you can only do limited data visualization, such as histogram for checking data distributions.
#
# 2. You should construct at least 3 machine learning models (no deep learning here), and **clearly** report your results.
#
# 3. You should use techniques (including but not limited to feature selection, data transformation, and standardization) to improve model performance.
#
# 4. You should structure your implementation using functions and classes to minimize code repetition and improve modularity, readability, and reusability. Ideally, I hope you can make your main code as short as possible.
#
#
# # Grading Policy:
#
# 1. Include at least two distinct types of visualizations to present your data analysis results. (5 pts)
#
# 2. Ensure that your implementation is free of logical errors in the machine learning workflow. (10 pts)
#
#    - **Please do not set up any random seed. You should repeat your experiments to reduce randomness.**
#
# 3. Make sure that you construct at least 3 different machine learning models. (5 pts)
#
# 3. Improve your models to achieve the best possible performance. Your grade will depend in part on the test error you report: **lower errors will result in higher scores**. This assignment includes a competitive component, as your results will be compared with those of your classmates. (10 pts)
#
# **Please report average relative test error since I will compare your results.**
#
# Temporary grading threshold (subject to change in a way that may benefit your grade):
#
#      performance | grade
#
#       Top 5%      |   10
#
#      5% - 20%     |   9
#
#      20% - 40%    |   8
#
#      40% - 70%    |   7
#
#      70% - 100%   |   6
#
# 4. Documentation, comments, code structures, and clearity of your results. (10 pts)
#
# # Submission:
#
# Render your Jupyter Notebook as a PDF file and then submit.
#
# # Comments:
#
# 1. Due to the time limitation, I do not expect detailed data analysis.
#
# 2. You can use any machine learning models, even if they are not covered in the lecture notes.
