# %% [markdown]
# # Worksheet: Torch
#
# In this worksheet, we will use Torch to train a general linear regression model. Compared with Worksheet 10, we will have more than 2 trainable parameters and matrix vector multiplicaton is used.

# %% [markdown]
# Deliverables: A plot containing training losses and test losses (4 pts).
#
# **Grading is based on participation and visualization.**

# %% [markdown]
# ## Class
#
# If time permits, please render your functions to a class.
