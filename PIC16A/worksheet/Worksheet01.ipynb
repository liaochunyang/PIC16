# %% [markdown]
# # Hello, PIC16A
#
# You can choose to open this file in JupyterLab or Notebook or VS code. I'd recommend Jupyter Notebook since that's what it's made for!
#
#
# ### Group Members and Roles
#
# - Group Member 1 (Role)
# - Group Member 2 (Role)
# - Group Member 3 (Role)
#
# **Add your names and roles beside the bullet points above if you work in a group. Individual work is also acceptable**
#
# #### This worksheet is graded based on:
# 1. Restart the kernel and run all before you submit. (2 pts)
# 2. Submit a pdf file, not .ipynb file. (3 pts)
# 3. Completion of the notebook. (5 pts)

# %% [markdown]
# ## Exercise 1: Introduce yourself
#
# There's plenty of time for this part of the activity, so please take your time. Some follow-up questions:
#
# 1. Your name.
# 2. Your area or planned area of study at UCLA.
# 3. Why you are interested in Python programming.
#
# Please tell me more about yourselves!

# %% [markdown]
# ## Exercise 2: Hello Markdown
#
# Throughout PIC16A, you will frequently be asked to write explanatory text in which you describe your problem-solving strategy and the structure of your code. One way to do this will be in comments and docstrings, which we will introduce later. Another important way is with *Markdown cells.* Markdown (https://en.wikipedia.org/wiki/Markdown#Example) is a simple, readable way to create formatted text. It was invented by John Gruber and Aaron Swartz. This cheatsheet (https://commonmark.org/help/) contains a useful and concise set of instructions for Markdown editing.
#
# To create a Markdown cell, first create a code cell like you did before. Then, with your cursor in the code cell, click the dropdown menu in the toolbar that says "Code".  Select "Markdown" from this menu instead.
#
# Return to the cell and type the following characters, exactly as they appear:
#
# `*To boldly go* **where no one has gone before.**`
#
# Then, "run" the Markdown cell (`shift + enter` again) to see your text rendered with italic and bold formatting.
#
# Now, work with your group to reproduce in Markdown the following algorithm for enjoying a relaxing cup of tea.
#
# <br>
#
# <figure class="image" style="width:40%">
#   <img src="https://raw.githubusercontent.com/liaochunyang/PIC16/refs/heads/main/PIC16A/images/making-tea.png" alt="A list of six items describing how to make tea. The list reads:
#     1. Boil water.
#     2. Place tea bag in mug.
#     3. Pour water in mug. **Be careful, water is hot!**
#     3. *Optional: add milk and/or sugar*.
#     4. Drink tea.
#         - `while cup is not empty`
#             - Carefully raise mug to mouth.
#             - Take a sip.
#     5. Clean mug. ">
#   <figcaption><i></i></figcaption>
# </figure>
#
#
# \[add markdown cell immediately below\]

# %% [markdown]
# # Exercise 3: Variables and Objects in Python
#
# *a)* In the code cell below, write the three lines:
# ```python
# x = 2
# x = [5]
# x = "a"
# ```
# **Print the value of `x` after each line.** Run the cell. Try running it multiple times. Observe the output. In a few words, what does this tell you about what happens, in terms of objects and variables? Write your answer in the space below the code cell.

# %%
# code here

# %% [markdown]
# *b)* Now write the three lines:
# ```python
# y = [1, 2, 3]
# y[0] = 8
# y.sort()
# ```
# Print the value and `id()` of `y` after each line. What does this tell you about what happens, in terms of objects and variables?

# %%
# code here

# %% [markdown]
# *c)* Write the four lines:
# ```python
# a = 0
# b = a
# a += 1
# a += 2
# ```
# After each line, print `a`, `b`, and their identities (once they've been defined). Is this the same as what you might have expected based on your previous programming experience in a language such as C++?

# %%
# code here

# %% [markdown]
# *d)* Write the four lines:
# ```python
# c = [0, 1, 2]
# d = c
# c += [3]
# c += [4, 5]
# ```
# After each line, print `c`, `d`, and their identities (once they've been defined). Is this the same as what you might have expected based on your previous programming experience in a language such as C++? How does it differ from your answer to the previous part? (It might help to google the phrase `mutable variable'.)

# %%
# code here

# %% [markdown]
# # Exercise 4: Built-In Functions
#
# For each of the following code cells:
#
# 1. Make a markdown cell above the code cell. Inside that markdown cell, write your hypothesis describing what the cell will print or otherwise achieve. There are several functions here that we haven't learned yet -- take your best guess! A couple of words per function (not per line of code) will suffice.
# 2. Then, run the cell to check your hypothesis.
# 3. After checking, feel free to modify the code cell to experiment with the functions and make sure everyone is clear on their operation.

# %%
p = ['t', 'e', 's', 't']
q = ['a', 'b', 'c', 'd']
r = [10, 20, 8, 17]

# %%
print(len(p))
print(len(p + q))
print(len([]))

# %%
t1 = ', '.join(q)
t2 = ''.join(p)
print(t1)
print(t2)
print(t1.upper())
print(t1.upper().lower())
print(''.join(q).split('b'))

# %%
print(t1.count(','))
print(t2.count('t'))

# %%
print(min(p))
print(max(q))
print(max(r))
print(sum(r))

# %%
print(range(10))
print(list(range(10)))
print(list(range(5,8)))
print(list(range(10,0)))
print(list(range(10,0,-1)))

# %%
print(sorted(p))
print(list(zip(p,q,r)))
print(list(zip(*zip(p,q,r))))

# %% [markdown]
# Great job! It's time to submit the worksheet.
#
# 1. PDF file: The Driver should **convert the worksheet to PDF** and then submit the PDF on Gradescope. There are a few valid ways to do this.
#
# - Choose `File -> Print Preview`. This will open a new window with a simplified view of the notebook suitable for printing. Choose the `Save as PDF` option from your print menu.
#
# - `File` -> `Download As` -> `HTML` on the Jupyter toolbar. Then, you save your notebook as an `HTML` file on your laptop. Open it and then right click to print the page. Choose the `Save as PDF` option from your print menu.
#
#
# 2. Only one member of the group needs to submit them, but make sure you add your group member as part of the group submission. Everyone else should then get an email accouncement from Gradescope.
