# %% [markdown]
# # Worksheet: CNN
#
# In this worksheet, you will construct a convolution neural network and train it using MNIST dataset. Report training accuracy and test accuracy, and visualize training(test) loss curve versus epochs.
#
# **Grading is based on participation.**
