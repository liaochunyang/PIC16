# %% [markdown]
# # Worksheet
#
# In this worksheet, you will construct a neural network using `Torch.nn.Module`. Training the neural network will also be discussed if time permits.
#
# **Grading is based on participation.**
