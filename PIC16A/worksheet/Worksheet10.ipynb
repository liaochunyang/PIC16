# %% [markdown]
# # Worksheet
#
# ### Group Members and Roles
#
# - Group Member 1 (Role)
# - Group Member 2 (Role)
# - Group Member 3 (Role)
#
# **Grading is based on completion.**

# %% [markdown]
# #### Step 1. read data set, then check the top 4 rows and last 2 rows.

# %%
url = 'https://raw.githubusercontent.com/liaochunyang/PIC16/refs/heads/main/PIC16A/data/ucla_basketball.csv'

# %% [markdown]
# #### Step 2. Fill NaN with 0

# %% [markdown]
# #### Step 3. Compute mean for each column

# %% [markdown]
# #### Step 4. Field Goal percentage for each player
#
# Add a new column to your pandas DataFrame with a column named FGP
#
# Field Goal Percentage (FGP) = FGM / FGA
#
# Round your answer to 2 decimal points

# %% [markdown]
# #### Step 5. Return players who played more than 1000 minutes

# %% [markdown]
# #### Step 6. Select players who shoot more than 50 three pointers (3PA>50) and compute average 3PM for those players

# %% [markdown]
# #### Step 7. Select players who play more than 800 minutes and compute the sum of their PTS.

# %% [markdown]
# #### Step 8. New dataframe with average statistics.
#
# Compute average PTS, average REB, average AST, average STL, and average BLK for each player and create a new dataFrame containing player name and computed statistics.
#
# average points = PTS/Game Played
#
# The new data frame should include columns ['name','PTS','REB','AST','STL','BLK'].
